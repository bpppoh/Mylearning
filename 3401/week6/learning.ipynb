# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def cv_show(img):
    cv2.imshow('Mean Filtered Image', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    for i in range(5) :
        cv2.waitKey(1)

# %%
def plt_show(img):
    plt.axis("off")
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
def prewitt_operator_meth(img) :
    mask_gx = np.array([[-1,0,1],[-1,0,1],[-1,0,1]],dtype='float16')
    mask_gy = np.array([[-1,-1,-1],[0,0,0],[1,1,1]],dtype='float16')
    gx = cv2.filter2D(img , -1 , mask_gx)
    gy = cv2.filter2D(img , -1 , mask_gy)
    out = np.sqrt(gx**2 + gy**2)
    return out

# %%
def edge_operator_meth(img, k):
    f = img.copy().astype(np.float16)
    out = np.zeros_like(img, dtype = 'float16')
    mask_gx = np.array([[-1, 0, 1], [-k, 0, k], [-1, 0, 1]] , dtype = 'float16') 
    mask_gy = np.array([[-1, -k, -1], [0, 0, 0], [1, k, 1]] , dtype = 'float16') 
 
    sz, sz = mask_gx.shape
    bd = sz // 2
    (m,n) = f.shape
    for i in range(bd,m-bd):
        for j in range(bd,n-bd):
            gx, gy = 0., 0.
            sub_f = f[i - bd : i + bd + 1, j - bd : j + bd + 1]
            gx = np.multiply(sub_f, mask_gx).sum() 
            gy = np.multiply(sub_f, mask_gy).sum()    
            out[i,j] = np.sqrt(gx**2 + gy**2)
    out[out>255.0] = 255.0
    return out.astype(np.uint8)

# %%
image = cv2.imread('../image/lena.jpg',0)
print(image.shape)
# Out:
# (512, 512)

# %%
out = edge_operator_meth(image, 1)
imgs = cv2.hconcat([image, out])
cv_show(imgs)
# Out:
# /var/folders/gk/pnmskwrx3732zbj001cxxq_m0000gn/T/ipykernel_95062/2882460644.py:16: RuntimeWarning: overflow encountered in scalar add
#   out[i,j] = np.sqrt(gx**2 + gy**2)
# /var/folders/gk/pnmskwrx3732zbj001cxxq_m0000gn/T/ipykernel_95062/2882460644.py:16: RuntimeWarning: overflow encountered in scalar power
#   out[i,j] = np.sqrt(gx**2 + gy**2)

# %%
def sobel_operator(img):
    gx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)  
    gy = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)  
    out = np.sqrt(gx**2 + gy**2)
    return out.astype(np.uint8)

# %%
out = edge_operator_meth(image, 2)
imgs = cv2.hconcat([image, out])
plt_show(imgs)
# Out:
# /var/folders/gk/pnmskwrx3732zbj001cxxq_m0000gn/T/ipykernel_95062/2882460644.py:16: RuntimeWarning: overflow encountered in scalar power
#   out[i,j] = np.sqrt(gx**2 + gy**2)
# /var/folders/gk/pnmskwrx3732zbj001cxxq_m0000gn/T/ipykernel_95062/2882460644.py:16: RuntimeWarning: overflow encountered in scalar add
#   out[i,j] = np.sqrt(gx**2 + gy**2)

# %%
out  = cv2.Canny(image, 50, 150)
imgs = cv2.hconcat([image, out])
plt_show(imgs)
