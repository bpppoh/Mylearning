# %%
import numpy as np
import cv2

# %%
img1 = cv2.imread("../image/lena.jpg" , cv2.IMREAD_COLOR)
img2 = cv2.imread("../image/lena.jpg" , cv2.IMREAD_GRAYSCALE)

# %%
print(cv2.IMREAD_COLOR)
print(cv2.IMREAD_GRAYSCALE)
# Out:
# 1
# 0

# %%
print(type(img2))
print(type(img1))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(img1.shape , img2.shape)
# Out:
# (512, 512, 3) (512, 512)
