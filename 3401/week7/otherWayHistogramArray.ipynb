# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../image/cameraman.tif' , 0)

# %%
hist_0 = cv2.calcHist([img],[0],None,[256],[0,256])
print(f"hist_0.shape : {hist_0.shape}")
print(hist_0)
# Out:
# hist_0.shape : (256, 1)
# [[ 102.]
#  [  76.]
#  [  89.]
#  [ 114.]
#  [ 159.]
#  [ 209.]
#  [ 335.]
#  [1173.]
#  [3523.]
#  [5129.]
#  [4490.]
#  [4980.]
#  [5762.]
#  [6212.]
#  [6067.]
#  [4480.]
#  [2805.]
#  [1375.]
#  [ 860.]
#  [ 625.]
#  [ 498.]
#  [ 503.]
#  [ 426.]
#  [ 430.]
#  [ 379.]
#  [ 398.]
#  [ 418.]
#  [ 402.]
#  [ 358.]
#  [ 362.]
#  [ 354.]
#  [ 349.]
#  [ 355.]
#  [ 381.]
#  [ 371.]
#  [ 379.]
#  [ 348.]
#  [ 375.]
#  [ 390.]
#  [ 398.]
#  [ 394.]
#  [ 349.]
#  [ 327.]
#  [ 345.]
#  [ 311.]
#  [ 263.]
#  [ 256.]
#  [ 279.]
#  [ 274.]
#  [ 258.]
#  [ 258.]
#  [ 245.]
#  [ 242.]
#  [ 261.]
#  [ 265.]
#  [ 268.]
#  [ 285.]
#  [ 276.]
#  [ 334.]
#  [ 308.]
#  [ 337.]
#  [ 309.]
#  [ 313.]
#  [ 370.]
#  [ 276.]
#  [ 301.]
#  [ 245.]
#  [ 230.]
#  [ 244.]
#  [ 242.]
#  [ 222.]
#  [ 217.]
#  [ 230.]
#  [ 238.]
#  [ 235.]
#  [ 224.]
#  [ 205.]
#  [ 220.]
#  [ 213.]
#  [ 208.]
#  [ 164.]
#  [ 203.]
#  [ 222.]
#  [ 216.]
#  [ 230.]
#  [ 243.]
#  [ 251.]
#  [ 281.]
# ...
