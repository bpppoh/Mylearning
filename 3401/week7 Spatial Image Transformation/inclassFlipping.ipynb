# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../image/cameraman.tif',0)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.show()

# %%
def hFlip(img) :
    out = np.zeros_like(img,dtype='uint8')
    h , w = img.shape
    for i in range(h) :
        for j in range(w) :
            out[i,j] = img[i,w-j-1]
    return out

hout = hFlip(img)
hconcat = cv2.hconcat([img,hout])
plt.imshow(hconcat,cmap='gray')
plt.axis('off')
plt.show()

# %%
def vFlip(img) :
    out = np.zeros_like(img,dtype='uint8')
    h , w = img.shape
    for i in range(h) :
        for j in range(w) :
            out[i,j] = img[h-i-1,j]
    return out

vout = vFlip(img)
vconcat = cv2.vconcat([img,vout])
plt.imshow(vconcat,cmap='gray')
plt.axis('off')
plt.show()

# %%
hvout = vFlip(hout)

row1 = cv2.hconcat([img,hout])
row2 = cv2.hconcat([vout,hvout])
fullImage = cv2.vconcat([row1,row2])
plt.imshow(fullImage,cmap='gray')
plt.axis('off')
plt.show()
